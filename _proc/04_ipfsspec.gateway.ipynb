# %% [raw]
# ---
# description: Gateway implementation for ipfsspec
# output-file: ipfsspec.gateway.html
# title: ipfsspec gateway
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(AsyncIPFSGateway)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/ipfsspec/gateway.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### AsyncIPFSGateway
#
# >      AsyncIPFSGateway (url=None, gateway_type='local')
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(GatewayState)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/ipfsspec/gateway.py#L318){target="_blank" style="float:right; font-size:smaller"}
#
# ### GatewayState
#
# >      GatewayState ()
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#| echo: false
#| output: asis
show_doc(MultiGateway)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/ipfsspec/gateway.py#L355){target="_blank" style="float:right; font-size:smaller"}
#
# ### MultiGateway
#
# >      MultiGateway (gws, max_backoff_rounds=40)
#
# Initialize self.  See help(type(self)) for accurate signature.
