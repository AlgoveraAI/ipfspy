# %% [raw]
# ---
# description: util functions for the ipfspy library
# output-file: utils.html
# title: utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
# #export
# GATEWAYS_API_READ = [
#     "https://ipfs.io/api/v0",
#     "https://gateway.pinata.cloud/api/v0",
#     "https://cloudflare-ipfs.com/api/v0",
#     "https://dweb.link/api/v0",
#     "https://ipfs.eth.aragon.network/api/v0",
#     "https://permaweb.eu.org/api/v0",
#     "https://nftstorage.link/api/v0",
#     "https://ipfs.lain.la/api/v0",
#     "https://ipfs.mihir.ch/api/v0",
#     "https://ipfs.telos.miami/api/v0",
#     "https://jorropo.net/api/v0",
#     "https://cf-ipfs.com/api/v0",
#     "https://cloudflare-ipfs.com/api/v0",
#     "https://gateway.ipfs.io/api/v0",
#     "https://infura-ipfs.io/api/v0",
#     "https://via0.com/api/v0",
#     "https://ipfs.azurewebsites.net/api/v0"
# ]

# GATEWAYS_API_WRITE = [
#     "https://ipfs.io/api/v0",
#     "https://gateway.pinata.cloud/api/v0",
#     "https://cloudflare-ipfs.com/api/v0",
#     "https://dweb.link/api/v0",
# ]

# %%
#|output: asis
#| echo: false
show_doc(parse_error_message)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/utils.py#L39){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse_error_message
#
# >      parse_error_message (response)
#
# Parse error message for raising exceptions
#
# |    | **Details** |
# | -- | ----------- |
# | response | Response object from requests |

# %%
#|output: asis
#| echo: false
show_doc(parse_response)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/utils.py#L20){target="_blank" style="float:right; font-size:smaller"}
#
# ### parse_response
#
# >      parse_response (response)
#
# Parse response object into JSON
#
# |    | **Details** |
# | -- | ----------- |
# | response | Response object |

# %%
#|output: asis
#| echo: false
show_doc(IPFSGateway)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/utils.py#L70){target="_blank" style="float:right; font-size:smaller"}
#
# ### IPFSGateway
#
# >      IPFSGateway (url, auth=None)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#|output: asis
#| echo: false
show_doc(dict_equal)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/utils.py#L231){target="_blank" style="float:right; font-size:smaller"}
#
# ### dict_equal
#
# >      dict_equal (*args)

# %%
#|output: asis
#| echo: false
show_doc(dict_hash)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/utils.py#L221){target="_blank" style="float:right; font-size:smaller"}
#
# ### dict_hash
#
# >      dict_hash (dictionary:Dict[str,Any])
#
# MD5 hash of a dictionary.

# %%
#|output: asis
#| echo: false
show_doc(dict_put)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/utils.py#L202){target="_blank" style="float:right; font-size:smaller"}
#
# ### dict_put
#
# >      dict_put (input_dict, keys, value)
#
# insert keys that are dot seperated (key1.key2.key3) recursively into a dictionary

# %%
#|output: asis
#| echo: false
show_doc(dict_get)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/utils.py#L183){target="_blank" style="float:right; font-size:smaller"}
#
# ### dict_get
#
# >      dict_get (input_dict, keys, default_value=False)
#
# get keys that are dot seperated (key1.key2.key3) recursively into a dictionary

# %%
#|output: asis
#| echo: false
show_doc(make_infura_auth)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/utils.py#L243){target="_blank" style="float:right; font-size:smaller"}
#
# ### make_infura_auth
#
# >      make_infura_auth (username, password)
