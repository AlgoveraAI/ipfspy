# %% [raw]
# ---
# description: Tracing implementation for ipfsspec
# output-file: ipfsspec.tracing.html
# title: ipfsspec tracing
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(GatewayTracer)
# Out:
# ---
#
# [source](https://github.com/AlgoveraAI/ipfspy/tree/master/blob/master/ipfspy/tracing.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### GatewayTracer
#
# >      GatewayTracer ()
#
# Initialize self.  See help(type(self)) for accurate signature.
