# %%
# default_exp estuaryapi

# %% [markdown]
# ## Estuary
# > Python API for interacting with Estuary

# %%
import requests

# %%
#export
def est_get_public_stats():
    return requests.get('https://api.estuary.tech/public/stats')

# %%
#export
def est_get_viewer(api_key):
    headers = {
    'Authorization': f'Bearer {api_key}',
    }

    response = requests.get('https://api.estuary.tech/viewer', headers=headers)
    return response

# %%
#export
def est_upload(api_key, path_to_file):
    headers = {
    'Authorization': f'Bearer {api_key}',
    # requests won't add a boundary if this header is set when you pass files=
    # 'Content-Type': 'multipart/form-data',
    }

    files = {
        'data': open('{path_to_file}', 'rb'),
    }

    response = requests.post('https://api.estuary.tech/content/add', headers=headers, files=files)
    return response

# %%
#export
def est_list_data(api_key):
    headers = {
    'Authorization': f'Bearer {api_key}',
    }

    response = requests.get('https://api.estuary.tech/content/list', headers=headers)
    return response

# %% [markdown]
# ### Estuary Collections

# %%
#export
# creating a collection
def est_create_collection(api_key, name, description):
    headers = {
    # Already added when you pass json= but not when you pass data=
    # 'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
    }

    json_data = {
        'name': f'{name}',
        'description': f'{description}',
    }

    response = requests.post('https://api.estuary.tech/collections/create', headers=headers, json=json_data)

    # Note: json_data will not be serialized by requests
    # exactly as it was in the original request.
    #data = '{ "name": "My super nice new collection", "description": "This collection holds only the best content" }'
    #response = requests.post('https://api.estuary.tech/collections/create', headers=headers, data=data)
    return response

# %%
#export
# Adding a file to a collection
def est_add_file_to_collection(api_key, cids: list, collection: str): 
    headers = {
        'Content-Type': 'application/json',
        'Authorization': f'Bearer {api_key}',
    }

    data = f'{ "contents": [], "cids": {cids}, "collection": {collection} }'

    response = requests.post('https://api.estuary.tech/collections/add-content', headers=headers, data=data)
    return response

# %% [markdown]
# # Main Estuary API
# > Below are all the commands available for interacting with Estuary

# %% [markdown]
# ### Standard IPFS Pinning API

# %%
#export
# list pins
def list_pins(api_key):
    headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
    }

    response = requests.get('https://api.estuary.tech/pinning/pins', headers=headers)
    return response.json()

# %%
#export
# add pin
def add_pin(api_key, name, cid):
    headers = {
    # Already added when you pass json= but not when you pass data=
    # 'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
    }

    json_data = {
        'name': name,
        'cid': cid,
    }

    response = requests.post('https://api.estuary.tech/pinning/pins', headers=headers, json=json_data)
    return response.json()

# %%
#export
# get pin by ID
def get_pin(api_key, pin_id):
    headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
    }

    response = requests.get(f'https://api.estuary.tech/pinning/pins/{pin_id}', headers=headers)
    return response.json()

# %%
#ignoretest
get_pin('EST85c4cdd4-21fc-4f2d-8e2a-aeb9dfb1364dARY', '028768691')
# Out:
# {'requestid': '28768691',
#  'status': 'pinned',
#  'created': '2022-05-06T16:04:59.480402Z',
#  'pin': {'cid': 'bafkreidqulmh3jp2oeea2fth7q3ilx3y456magfqhnj22zmz6gnz4ijrhy',
#   'name': 'DefiSquad_Compound_StableCoin_BorrowingStrategy.jpg',
#   'origins': None,
#   'meta': None},
#  'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#  'info': None}

# %%
#ignoretest
list_pins('EST85c4cdd4-21fc-4f2d-8e2a-aeb9dfb1364dARY')
# Out:
# {'count': 34,
#  'results': [{'requestid': '28768691',
#    'status': 'pinned',
#    'created': '2022-05-06T16:04:59.480402Z',
#    'pin': {'cid': 'bafkreidqulmh3jp2oeea2fth7q3ilx3y456magfqhnj22zmz6gnz4ijrhy',
#     'name': 'DefiSquad_Compound_StableCoin_BorrowingStrategy.jpg',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '28768665',
#    'status': 'pinned',
#    'created': '2022-05-06T16:04:11.256738Z',
#    'pin': {'cid': 'bafkreidqulmh3jp2oeea2fth7q3ilx3y456magfqhnj22zmz6gnz4ijrhy',
#     'name': 'DefiSquad_Compound_StableCoin_BorrowingStrategy.jpg',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '28768115',
#    'status': 'pinned',
#    'created': '2022-05-06T15:32:11.217795Z',
#    'pin': {'cid': 'bafkreidqulmh3jp2oeea2fth7q3ilx3y456magfqhnj22zmz6gnz4ijrhy',
#     'name': 'DefiSquad_Compound_StableCoin_BorrowingStrategy.jpg',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '27892784',
#    'status': 'pinned',
#    'created': '2022-04-18T00:47:45.447178Z',
#    'pin': {'cid': 'QmWAQjxm6CKaAjHjwPSqWmN8RMecuHS1bxEufqCNVSq96e',
#     'name': 'compound.csv',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '27469875',
#    'status': 'pinned',
#    'created': '2022-04-12T14:46:24.791383Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '27347700',
#    'status': 'pinned',
#    'created': '2022-04-11T17:58:18.764349Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '26185698',
#    'status': 'pinned',
#    'created': '2022-04-01T15:29:08.663122Z',
#    'pin': {'cid': 'bafkreibhpctrxncmqsfmgduiyvbmb7uj7iwqkbbpap4sw76xankiry2yzi',
#     'name': '898 Fluorescent.png',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '26185692',
#    'status': 'pinned',
#    'created': '2022-04-01T15:28:58.492927Z',
#    'pin': {'cid': 'bafkreibhpctrxncmqsfmgduiyvbmb7uj7iwqkbbpap4sw76xankiry2yzi',
#     'name': '898 Fluorescent.png',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '26012760',
#    'status': 'pinned',
#    'created': '2022-03-31T17:33:47.895729Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '26012063',
#    'status': 'pinned',
#    'created': '2022-03-31T17:16:23.896044Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '26012057',
#    'status': 'pinned',
#    'created': '2022-03-31T17:15:16.637877Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '26006929',
#    'status': 'pinned',
#    'created': '2022-03-31T16:32:54.601444Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '26003435',
#    'status': 'pinned',
#    'created': '2022-03-31T15:55:56.416387Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '26003393',
#    'status': 'pinned',
#    'created': '2022-03-31T15:51:54.182324Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25756171',
#    'status': 'pinned',
#    'created': '2022-03-30T16:29:34.765234Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25755816',
#    'status': 'pinned',
#    'created': '2022-03-30T14:55:17.996606Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25580703',
#    'status': 'pinned',
#    'created': '2022-03-29T16:40:34.170988Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25570673',
#    'status': 'pinned',
#    'created': '2022-03-29T15:21:32.63734Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25570134',
#    'status': 'pinned',
#    'created': '2022-03-29T15:15:54.787533Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25570085',
#    'status': 'pinned',
#    'created': '2022-03-29T15:09:05.023011Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25563521',
#    'status': 'pinned',
#    'created': '2022-03-29T14:24:56.258102Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25460835',
#    'status': 'pinned',
#    'created': '2022-03-29T02:10:54.55596Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25453727',
#    'status': 'pinned',
#    'created': '2022-03-29T01:05:48.290907Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25424251',
#    'status': 'pinned',
#    'created': '2022-03-28T21:11:46.622678Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25423483',
#    'status': 'pinned',
#    'created': '2022-03-28T20:48:06.697183Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '25421455',
#    'status': 'pinned',
#    'created': '2022-03-28T20:44:42.593334Z',
#    'pin': {'cid': 'bafkqaflimvwgy3zaorugs4zanfzsayjaorsxg5ak',
#     'name': 'test.md',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '24323945',
#    'status': 'pinned',
#    'created': '2022-03-20T21:10:22.811379Z',
#    'pin': {'cid': 'bafkreieftkqksqyhydpeg5qobwrpl7a6bghxvadnaocke7e7p3mirmlvya',
#     'name': 'channels.feather',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '23944337',
#    'status': 'pinned',
#    'created': '2022-03-17T21:04:34.750558Z',
#    'pin': {'cid': 'bafybeifdf4nnnvbkjpw5awwlgxag72j7aj7w7wohstpfxub3xlwbw2ttsa',
#     'name': 'train_val_30.zip',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '23944324',
#    'status': 'pinned',
#    'created': '2022-03-17T21:01:37.380832Z',
#    'pin': {'cid': 'bafybeiagbm6mhshlbuntcli7b2yon36ijxxbdktyd3bjpdypeskuldiyjq',
#     'name': 'test_30.zip',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '23458559',
#    'status': 'pinned',
#    'created': '2022-03-15T12:02:12.526119Z',
#    'pin': {'cid': 'bafybeie35lhoreolmvqmqpoyoz2vxtulniifwddlmfnv3xs5bge3xxtfsi',
#     'name': 'sample_16.zip',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '23443010',
#    'status': 'pinned',
#    'created': '2022-03-15T10:11:57.015522Z',
#    'pin': {'cid': 'bafybeicjgvknun4nwj2nfk3mmvi44au4stbylcskxpogoyx7ekqgsifvqq',
#     'name': 'train_val_16.zip',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '23441886',
#    'status': 'pinned',
#    'created': '2022-03-15T10:00:05.239351Z',
#    'pin': {'cid': 'bafybeiabminw4uxievfpqjtx6nglat7larewhbcz7qmvgjupluxusrkij4',
#     'name': 'test_16.zip',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '22684096',
#    'status': 'pinned',
#    'created': '2022-03-11T10:55:17.753001Z',
#    'pin': {'cid': 'bafybeiekwob56fan4lugtivo7bei7pnl55vnmieesmxd3krrdu35nc6rhe',
#     'name': 'train_val.zip',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None},
#   {'requestid': '22669248',
#    'status': 'pinned',
#    'created': '2022-03-11T09:39:05.166065Z',
#    'pin': {'cid': 'bafybeihreajb6qznddbs2kjmbcrlsjw3eo5bv4zpjl7mm3rpwu57fxiwg4',
#     'name': 'test.zip',
#     'origins': None,
#     'meta': None},
#    'delegates': ['/ip4/3.134.223.177/tcp/6745/p2p/12D3KooWN8vAoGd6eurUSidcpLYguQiGZwt4eVgDvbgaS7kiGTup'],
#    'info': None}]}

# %%
#export
# replace pin by ID
def replace_pin(api_key, pin_id):
    headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
    }

    response = requests.post(f'https://api.estuary.tech/pinning/pins/{pin_id}', headers=headers)
    return response.json()

# %%
#export
# remove pin by ID
def remove_pin(api_key, pin_id):
    headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
    }

    response = requests.delete(f'https://api.estuary.tech/pinning/pins/{pin_id}', headers=headers)
    return response.json()

# %% [markdown]
# ### Collections

# %%
#export
# create new collection
def create_coll(api_key, name, description):
    headers = {
    # Already added when you pass json= but not when you pass data=
    # 'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
    }

    json_data = {
        'name': name,
        'description': description,
    }

    response = requests.post('https://api.estuary.tech/collections/create', headers=headers, json=json_data)
    return response.json()

# %%
#export
# add content
def add_content(api_key, collection_id):
    headers = {
    # Already added when you pass json= but not when you pass data=
    # 'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
    }

    json_data = {
        'contents': [],
        'cids': [],
        'collection': collection_id,
    }

    response = requests.post('https://api.estuary.tech/collections/add-content', headers=headers, json=json_data)
    return response.json()

# %%
#export
# list collections
def list_colls(api_key):
    headers = {
    'Authorization': f'Bearer {api_key}',
    }

    response = requests.get('https://api.estuary.tech/collections/list', headers=headers)
    return response.json()

# %%
#export
# list collection content
def list_coll_content(api_key, collection_id):
    headers = {
    'Authorization': f'Bearer {api_key}',
    }

    response = requests.get(f'https://api.estuary.tech/collections/content/{collection_id}', headers=headers)
    return response.json()

# %%
#export
# FS list content of a path
def list_content_path(api_key, collection):
    headers = {
    'Authorization': f'Bearer {api_key}',
    }

    params = {
        'col': collection,
    }

    response = requests.get('https://api.estuary.tech/collections/fs/list', params=params, headers=headers)
    return response.json()

# %%
#export
# FS add content to path
def add_content_path(api_key, collection):
    headers = {
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
    }

    params = {
        'col': collection,
    }

    response = requests.post('https://api.estuary.tech/collections/fs/add', params=params, headers=headers)
    return response.json()

# %% [markdown]
# ### Estuary base API

# %%
#export
# add client safe upload key
def add_key(api_key, expiry='24h'):
    headers = {
    'Authorization': f'Bearer {api_key}',
    'Accept': 'application/json',
    }

    params = {
        'perms': 'upload',
        'expiry': expiry,
    }

    response = requests.post('https://api.estuary.tech/user/api-keys', params=params, headers=headers)
    return response.json()

# %%
#export
# add data
def add_data(api_key, path_to_file):
    headers = {
    'Authorization': f'Bearer {api_key}',
    'Accept': 'application/json',
    # requests won't add a boundary if this header is set when you pass files=
    # 'Content-Type': 'multipart/form-data',
    }

    files = {
        'data': open(path_to_file, 'rb'),
    }

    response = requests.post('https://api.estuary.tech/content/add', headers=headers, files=files)
    return response.json()

# %%
#export
# add CID
def add_cid(api_key, name, root):
    headers = {
    # Already added when you pass json= but not when you pass data=
    # 'Content-Type': 'application/json',
    'Authorization': f'Bearer {api_key}',
    }

    json_data = {
        'name': name,
        'root': root,
    }

    response = requests.post('https://api.estuary.tech/content/add-ipfs', headers=headers, json=json_data)
    return response.json()

# %%
#export
# add CAR
def add_car(api_key, path_to_file):
    headers = {
    'Authorization': f'Bearer {api_key}',
    'Accept': 'application/json',
    }

    with open(path_to_file, 'rb') as f:
        data = f.read()

    response = requests.post('https://api.estuary.tech/content/add-car', headers=headers, data=data)
    return response.json()

# %%
#export
# make deal with specific provider
def make_deal(api_key):
    headers = {
    'Authorization': f'Bearer {api_key}',
    }

    json_data = {
        'content': content,
    }

    response = requests.post(f'https://api.estuary.tech/deals/make/{provider}', headers=headers, json=json_data)
    return response.json()

# %%
#export
# data by CID
def add_data_cid(api_key, cid: str):
    headers = {
    'Authorization': f'Bearer {api_key}',
    }
    
    response = requests.get(f'https://api.estuary.tech/content/by-cid/{cid}', headers=headers)
    return response.json()

# %%
#export
# list data
def list_data(api_key):
    headers = {
    'Authorization': f'Bearer {api_key}',
    }
    
    response = requests.get('https://api.estuary.tech/content/stats', headers=headers)
    return response.json()

# %%
#export
# list deals
def list_deals(api_key):
    headers = {
    'Authorization': f'Bearer {api_key}',
    }
    
    response = requests.get('https://api.estuary.tech/content/deals', headers=headers)
    return response.json()

# %%
#export
# get deal status by id
def get_deal_status(api_key, deal_id):
    headers = {
    'Authorization': f'Bearer {api_key}',
    }
    
    response = requests.get(f'https://api.estuary.tech/content/status/{deal_id}', headers=headers)
    return response.json()

# %%
#export
# get Estuary node stats
def get_node_stats():
    response = requests.get('https://api.estuary.tech/public/stats')
    return response.json()

# %%
#export
# get on chain deal data
def get_deal_data():
    response = requests.get('https://api.estuary.tech/public/metrics/deals-on-chain')
    return response.json()

# %%
#export
# get miner query ask
def get_miner_ask(id):
    response = requests.get(f'https://api.estuary.tech/public/miners/storage/query/{id}')
    return response.json()

# %%
#export
# get failure logs by provider
def get_failure_logs(id):
    response = requests.get(f'https://api.estuary.tech/public/miners/failures/{id}')
    return response.json()

# %%
#export
# get deal logs by provider
def get_deal_logs(provider_id):
    response = requests.get(f'https://api.estuary.tech/public/miners/deals/{provider_id}')
    return response.json()

# %%
#export
# get provider stats
def get_provider_stats(provider_id):
    response = requests.get(f'https://api.estuary.tech/public/miners/stats/{provider_id}')
    return response.json()

# %%
#export
# list providers
def list_providers():
    response = requests.get('https://api.estuary.tech/public/miners')
    return response.json()
